# %%
import os
import sys
import shutil
import xml.etree.ElementTree as ET
from utils.finder import find_leafes
from utils.dicom_to_nifti import single_label
# from utils.dicom_to_nifti import dicom_read_LIDC
from utils.dicom_to_nifti import dicom_read_LIDC_CT
from utils.dicom_to_nifti import dicom_read_LIDC_CT_and_label
from utils.dicom_to_nifti import read_RT_struct
from utils import convert
import csv
import pydicom
import SimpleITK as sitk
import numpy as np
import itk
import rt_utils
import matplotlib.pyplot as plt
# from convert

# %%
dir_base = r'/media/terese/New Volume1/Lung_cancer_project/ISP_dataset/DICOM_Data'


annotation_dir = r''

# output = r'/media/terese/New Volume1/Lung_cancer_project/Nifty_data_LIDC-IDRI'
output = r'/media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data'

# %%
bloop =False
no_rt_struct_files = []
multi_rt_struct = []
multi_ct = []
om = 0
for case_folder in os.listdir(dir_base):
    if len(case_folder) > 5:
        # If the folder name is more than just the case number it has no structure files. No not process struct files of these
        idx = case_folder.find('_')
        case_num = case_folder[:idx+1]
        no_rt_struct_files.append(case_num)
    else:
        print('case num: ', case_folder)
        om+=1
        # if om<4:
        #     continue
        

        CT_processed =False
        case_num = case_folder
        data_folders = os.listdir(os.path.join(dir_base, case_folder))
        for data_f in data_folders: #Folders separating CT scans from RT struct files in each case folder
            # print(len(data_f))
            files = os.listdir(os.path.join(dir_base, case_folder, data_f))
            print(data_f, len(data_f))
            if len(files) > 1:    #If there are more than 1 file it is the CT scan series
                if len(files)<100:
                    print(f'Case: {case_num} has more RT struct files than 1! N files in folder data_f: {len(files)}, {files}')
                    multi_rt_struct.append(case_num)
                    # raise f'Case: {case_num} has more RT struct files than 1! N files in folder data_f: {len(files)}, {files}'
                
                if CT_processed:
                    print(f'Case {case_num} contains several folders with more than one file. Excluding from processing')
                    multi_ct.append(case_num)
                    continue
                CT_series_path = os.path.join(dir_base, case_folder, data_f)
                

                case_path = os.path.join(output, case_num)
                if not os.path.isdir(case_path):
                    os.mkdir(case_path)
                output_dir = os.path.join(case_path, 'images')
                if not os.path.isdir(output_dir):
                    os.mkdir(output_dir)
                if not os.path.exists(os.path.join(output_dir, case_num + '_image.nii.gz')):
                    CT_image = dicom_read_LIDC_CT(CT_series_path, output_dir = output_dir, case_num=case_num, save_ims=True)
                CT_processed = True
            elif len(files) == 1:  # If there is only one file it is the RT struct file
                print(f'Case {case_num} RT struct file')
                path = os.path.join(dir_base, case_folder, data_f)
                files = os.listdir(path)


                case_path = os.path.join(output, case_num)
                
                case_im_path = os.path.join(case_path, 'images')
                if not os.path.isdir(case_im_path):
                    os.mkdir(case_im_path)
                if os.path.exists(os.path.join(case_im_path, case_num + '_image.nii.gz')):
                    CT_image = sitk.ReadImage(os.path.join(case_im_path, case_num + '_image.nii.gz'))
                else: 
                    CT_image = dicom_read_LIDC_CT(CT_series_path, output_dir = case_im_path, case_num=case_num, save_ims=True)
                output_mask_dir = os.path.join(case_path, 'labels')
                # read_RT_struct(RT_struct_path, CT_series_path, CT_image, output_dir=output_mask_dir, save_num=case_num)
                
                RT_struct_path = os.path.join(path, files[0])
                mask_dir, ct_dir, CT_sitk, save_num = RT_struct_path, CT_series_path, CT_image, case_num

                if (not output_mask_dir == None) and  not os.path.exists(output_mask_dir):
                    os.makedirs(output_mask_dir)
                rtstruct = rt_utils.RTStructBuilder.create_from(
                dicom_series_path=ct_dir, 
                rt_struct_path=mask_dir
                )
                struct_names = rtstruct.get_roi_names()
                print(f'Number of files in rt struct {len(struct_names)}')
                im_orig = CT_sitk.GetOrigin()
                im_spacing = CT_sitk.GetSpacing()
                im_direction = CT_sitk.GetDirection()
                im_size = CT_sitk.GetSize()
                # print(im_orig)
                # print(im_spacing)
                # print(im_direction)
                # print(im_size)
                for struct_num, struct in enumerate(struct_names):
                    # struct_array = rtstruct.get_roi_mask_by_name(struct)    # Include .astype(int) to convert from bool to int
                    struct_array = rtstruct.get_roi_mask_by_number(struct_num)
                    # if 'Nodule' in struct:
                        # print(struct)
                        # print(np.where(struct_array ==1))

                    struct_sitk = convert.correct_struct_image(struct_array, CT_sitk)

                    
                    
                    # struct_sitk = sitk.GetImageFromArray(struct_array)
                    
                    # struct_sitk.SetOrigin(im_orig)
                    # struct_sitk.SetSpacing(im_spacing)
                    # struct_sitk.SetDirection(im_direction)



                    if not output_mask_dir == None:
                        if 'Nodule' in struct:
                            # continue
                            struct = 'Nodule_seg_1'
                        elif 'Lung' in struct:
                            struct = struct[:5] + '_lung_seg'
                        else: 
                            raise f'Image is neither nodule nor lung. Struct name: {struct}'
                        filename = save_num + "_" + struct + ".nii.gz"
                        filepath = os.path.join(output_mask_dir, filename)
                        j=2
                        while os.path.exists(filepath) and ('Nodule' in struct):
                            struct = 'Nodule_seg_' + str(j)
                            filename = save_num + "_" + struct + ".nii.gz"
                            filepath = os.path.join(output_mask_dir, filename)
                            j+=1

                        print(f'Saving struct {struct} to {filepath}')
                        writer = sitk.ImageFileWriter()
                        writer.SetFileName(filepath)
                        writer.Execute(struct_sitk)
    #             bloop = True
    #             break
    #         if bloop:
    #             break
    # if bloop:
    #     break
print(f'\n\n{len(no_rt_struct_files)} Files with no RT struct file: {no_rt_struct_files}')
print(f'\n{len(multi_rt_struct)} files with more than one RT struct file: {multi_rt_struct}')
if len(multi_ct)> 0:
    print(f'\n\n{len(multi_ct)} Files with multiple CT files: {multi_ct}')
# Out:
# case num:  00001
# S70 3
# S7110 5
# Case 00001 RT struct file
# Number of files in rt struct 25
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00001/labels/00001_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00001/labels/00001_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_70 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00001/labels/00001_Nodule_seg_70.nii.gz
# Saving struct Nodule_seg_71 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00001/labels/00001_Nodule_seg_71.nii.gz
# Saving struct Nodule_seg_72 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00001/labels/00001_Nodule_seg_72.nii.gz
# Saving struct Nodule_seg_73 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00001/labels/00001_Nodule_seg_73.nii.gz
# Saving struct Nodule_seg_74 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00001/labels/00001_Nodule_seg_74.nii.gz
# Saving struct Nodule_seg_75 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00001/labels/00001_Nodule_seg_75.nii.gz
# Saving struct Nodule_seg_76 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00001/labels/00001_Nodule_seg_76.nii.gz
# Saving struct Nodule_seg_77 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00001/labels/00001_Nodule_seg_77.nii.gz
# Saving struct Nodule_seg_78 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00001/labels/00001_Nodule_seg_78.nii.gz
# Saving struct Nodule_seg_79 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00001/labels/00001_Nodule_seg_79.nii.gz
# Saving struct Nodule_seg_80 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00001/labels/00001_Nodule_seg_80.nii.gz
# Saving struct Nodule_seg_81 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00001/labels/00001_Nodule_seg_81.nii.gz
# Saving struct Nodule_seg_82 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00001/labels/00001_Nodule_seg_82.nii.gz
# Saving struct Nodule_seg_83 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00001/labels/00001_Nodule_seg_83.nii.gz
# Saving struct Nodule_seg_84 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00001/labels/00001_Nodule_seg_84.nii.gz
# Saving struct Nodule_seg_85 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00001/labels/00001_Nodule_seg_85.nii.gz
# Saving struct Nodule_seg_86 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00001/labels/00001_Nodule_seg_86.nii.gz
# Saving struct Nodule_seg_87 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00001/labels/00001_Nodule_seg_87.nii.gz
# Saving struct Nodule_seg_88 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00001/labels/00001_Nodule_seg_88.nii.gz
# Saving struct Nodule_seg_89 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00001/labels/00001_Nodule_seg_89.nii.gz
# Saving struct Nodule_seg_90 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00001/labels/00001_Nodule_seg_90.nii.gz
# Saving struct Nodule_seg_91 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00001/labels/00001_Nodule_seg_91.nii.gz
# Saving struct Nodule_seg_92 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00001/labels/00001_Nodule_seg_92.nii.gz
#
#
# 0 Files with no RT struct file: []
#
# 0 files with more than one RT struct file: []
# case num:  00002
# S70 3
# S7050 5
# Case 00002 RT struct file
# Number of files in rt struct 3
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00002/labels/00002_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00002/labels/00002_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_3 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00002/labels/00002_Nodule_seg_3.nii.gz
#
#
# 0 Files with no RT struct file: []
#
# 0 files with more than one RT struct file: []
# case num:  00003
# S70 3
# S7080 5
# Case 00003 RT struct file
# Number of files in rt struct 5
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00003/labels/00003_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00003/labels/00003_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_7 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00003/labels/00003_Nodule_seg_7.nii.gz
# Saving struct Nodule_seg_8 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00003/labels/00003_Nodule_seg_8.nii.gz
# Saving struct Nodule_seg_9 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00003/labels/00003_Nodule_seg_9.nii.gz
#
#
# 0 Files with no RT struct file: []
#
# 0 files with more than one RT struct file: []
# case num:  00004
# S70 3
# S7070 5
# Case 00004 RT struct file
# Number of files in rt struct 4
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00004/labels/00004_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00004/labels/00004_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_7 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00004/labels/00004_Nodule_seg_7.nii.gz
# Saving struct Nodule_seg_8 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00004/labels/00004_Nodule_seg_8.nii.gz
#
#
# 0 Files with no RT struct file: []
#
# 0 files with more than one RT struct file: []
# case num:  00005
# S85020 6
# S85090 6
# Case 00005 RT struct file
# Number of files in rt struct 12
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00005/labels/00005_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00005/labels/00005_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_21 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00005/labels/00005_Nodule_seg_21.nii.gz
# Saving struct Nodule_seg_22 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00005/labels/00005_Nodule_seg_22.nii.gz
# Saving struct Nodule_seg_23 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00005/labels/00005_Nodule_seg_23.nii.gz
# Saving struct Nodule_seg_24 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00005/labels/00005_Nodule_seg_24.nii.gz
# Saving struct Nodule_seg_25 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00005/labels/00005_Nodule_seg_25.nii.gz
# Saving struct Nodule_seg_26 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00005/labels/00005_Nodule_seg_26.nii.gz
# Saving struct Nodule_seg_27 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00005/labels/00005_Nodule_seg_27.nii.gz
# Saving struct Nodule_seg_28 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00005/labels/00005_Nodule_seg_28.nii.gz
# Saving struct Nodule_seg_29 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00005/labels/00005_Nodule_seg_29.nii.gz
# Saving struct Nodule_seg_30 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00005/labels/00005_Nodule_seg_30.nii.gz
#
#
# 0 Files with no RT struct file: []
#
# 0 files with more than one RT struct file: []
# case num:  00006
# S70 3
# S7050 5
# Case 00006 RT struct file
# Number of files in rt struct 2
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00006/labels/00006_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00006/labels/00006_Right_lung_seg.nii.gz
#
#
# 0 Files with no RT struct file: []
#
# 0 files with more than one RT struct file: []
# case num:  00007
# S50 3
# S5040 5
# Case 00007 RT struct file
# Number of files in rt struct 2
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00007/labels/00007_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00007/labels/00007_Right_lung_seg.nii.gz
#
#
# 0 Files with no RT struct file: []
#
# 0 files with more than one RT struct file: []
# case num:  00008
# S70 3
# S7040 5
# Case 00008 RT struct file
# Number of files in rt struct 6
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00008/labels/00008_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00008/labels/00008_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_9 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00008/labels/00008_Nodule_seg_9.nii.gz
# Saving struct Nodule_seg_10 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00008/labels/00008_Nodule_seg_10.nii.gz
# Saving struct Nodule_seg_11 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00008/labels/00008_Nodule_seg_11.nii.gz
# Saving struct Nodule_seg_12 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00008/labels/00008_Nodule_seg_12.nii.gz
#
#
# 0 Files with no RT struct file: []
#
# 0 files with more than one RT struct file: []
# case num:  00009
# S50 3
# S5070 5
# Case 00009 RT struct file
# Number of files in rt struct 6
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00009/labels/00009_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00009/labels/00009_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_9 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00009/labels/00009_Nodule_seg_9.nii.gz
# Saving struct Nodule_seg_10 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00009/labels/00009_Nodule_seg_10.nii.gz
# Saving struct Nodule_seg_11 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00009/labels/00009_Nodule_seg_11.nii.gz
# Saving struct Nodule_seg_12 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00009/labels/00009_Nodule_seg_12.nii.gz
#
#
# 0 Files with no RT struct file: []
#
# 0 files with more than one RT struct file: []
# case num:  00010
# S70 3
# S7050 5
# Case 00010 RT struct file
# Number of files in rt struct 2
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00010/labels/00010_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00010/labels/00010_Right_lung_seg.nii.gz
#
#
# 0 Files with no RT struct file: []
#
# 0 files with more than one RT struct file: []
# case num:  00011
# S50 3
# S5050 5
# Case 00011 RT struct file
# Number of files in rt struct 6
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00011/labels/00011_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00011/labels/00011_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_9 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00011/labels/00011_Nodule_seg_9.nii.gz
# Saving struct Nodule_seg_10 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00011/labels/00011_Nodule_seg_10.nii.gz
# Saving struct Nodule_seg_11 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00011/labels/00011_Nodule_seg_11.nii.gz
# Saving struct Nodule_seg_12 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00011/labels/00011_Nodule_seg_12.nii.gz
#
#
# 0 Files with no RT struct file: []
#
# 0 files with more than one RT struct file: []
# case num:  00012
# S50 3
# S5060 5
# Case 00012 RT struct file
# Number of files in rt struct 10
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00012/labels/00012_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00012/labels/00012_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_17 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00012/labels/00012_Nodule_seg_17.nii.gz
# Saving struct Nodule_seg_18 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00012/labels/00012_Nodule_seg_18.nii.gz
# Saving struct Nodule_seg_19 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00012/labels/00012_Nodule_seg_19.nii.gz
# Saving struct Nodule_seg_20 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00012/labels/00012_Nodule_seg_20.nii.gz
# Saving struct Nodule_seg_21 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00012/labels/00012_Nodule_seg_21.nii.gz
# Saving struct Nodule_seg_22 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00012/labels/00012_Nodule_seg_22.nii.gz
# Saving struct Nodule_seg_23 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00012/labels/00012_Nodule_seg_23.nii.gz
# Saving struct Nodule_seg_24 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00012/labels/00012_Nodule_seg_24.nii.gz
#
#
# 0 Files with no RT struct file: []
#
# 0 files with more than one RT struct file: []
# case num:  00013
# S70 3
# S7050 5
# Case 00013 RT struct file
# Number of files in rt struct 3
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00013/labels/00013_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00013/labels/00013_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_3 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00013/labels/00013_Nodule_seg_3.nii.gz
#
#
# 0 Files with no RT struct file: []
#
# 0 files with more than one RT struct file: []
#
#
# 1 Files with no RT struct file: ['00014_']
#
# 0 files with more than one RT struct file: []
# case num:  00015
# S50 3
# S5050 5
# Case 00015 RT struct file
# Number of files in rt struct 4
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00015/labels/00015_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00015/labels/00015_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_5 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00015/labels/00015_Nodule_seg_5.nii.gz
# Saving struct Nodule_seg_6 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00015/labels/00015_Nodule_seg_6.nii.gz
#
#
# 1 Files with no RT struct file: ['00014_']
#
# 0 files with more than one RT struct file: []
# case num:  00016
# S60 3
# S6050 5
# Case 00016 RT struct file
# Number of files in rt struct 5
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00016/labels/00016_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00016/labels/00016_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_7 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00016/labels/00016_Nodule_seg_7.nii.gz
# Saving struct Nodule_seg_8 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00016/labels/00016_Nodule_seg_8.nii.gz
# Saving struct Nodule_seg_9 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00016/labels/00016_Nodule_seg_9.nii.gz
#
#
# 1 Files with no RT struct file: ['00014_']
#
# 0 files with more than one RT struct file: []
# case num:  00017
# S50 3
# S5050 5
# Case 00017 RT struct file
# Number of files in rt struct 2
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00017/labels/00017_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00017/labels/00017_Right_lung_seg.nii.gz
#
#
# 1 Files with no RT struct file: ['00014_']
#
# 0 files with more than one RT struct file: []
# case num:  00018
# S50 3
# S5050 5
# Case 00018 RT struct file
# Number of files in rt struct 14
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00018/labels/00018_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00018/labels/00018_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_25 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00018/labels/00018_Nodule_seg_25.nii.gz
# Saving struct Nodule_seg_26 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00018/labels/00018_Nodule_seg_26.nii.gz
# Saving struct Nodule_seg_27 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00018/labels/00018_Nodule_seg_27.nii.gz
# Saving struct Nodule_seg_28 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00018/labels/00018_Nodule_seg_28.nii.gz
# Saving struct Nodule_seg_29 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00018/labels/00018_Nodule_seg_29.nii.gz
# Saving struct Nodule_seg_30 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00018/labels/00018_Nodule_seg_30.nii.gz
# Saving struct Nodule_seg_31 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00018/labels/00018_Nodule_seg_31.nii.gz
# Saving struct Nodule_seg_32 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00018/labels/00018_Nodule_seg_32.nii.gz
# Saving struct Nodule_seg_33 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00018/labels/00018_Nodule_seg_33.nii.gz
# Saving struct Nodule_seg_34 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00018/labels/00018_Nodule_seg_34.nii.gz
# Saving struct Nodule_seg_35 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00018/labels/00018_Nodule_seg_35.nii.gz
# Saving struct Nodule_seg_36 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00018/labels/00018_Nodule_seg_36.nii.gz
#
#
# 1 Files with no RT struct file: ['00014_']
#
# 0 files with more than one RT struct file: []
# case num:  00019
# S80 3
# S8040 5
# Case 00019 RT struct file
# Number of files in rt struct 9
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00019/labels/00019_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00019/labels/00019_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_15 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00019/labels/00019_Nodule_seg_15.nii.gz
# Saving struct Nodule_seg_16 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00019/labels/00019_Nodule_seg_16.nii.gz
# Saving struct Nodule_seg_17 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00019/labels/00019_Nodule_seg_17.nii.gz
# Saving struct Nodule_seg_18 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00019/labels/00019_Nodule_seg_18.nii.gz
# Saving struct Nodule_seg_19 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00019/labels/00019_Nodule_seg_19.nii.gz
# Saving struct Nodule_seg_20 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00019/labels/00019_Nodule_seg_20.nii.gz
# Saving struct Nodule_seg_21 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00019/labels/00019_Nodule_seg_21.nii.gz
#
#
# 1 Files with no RT struct file: ['00014_']
#
# 0 files with more than one RT struct file: []
# case num:  00020
# S100 4
# S500000 7
# Case: 00020 has more RT struct files than 1! N files in folder data_f: 23, ['I10', 'I100', 'I110', 'I120', 'I130', 'I140', 'I150', 'I160', 'I170', 'I180', 'I190', 'I20', 'I200', 'I210', 'I220', 'I230', 'I30', 'I40', 'I50', 'I60', 'I70', 'I80', 'I90']
# Case 00020 contains several folders with more than one file. Excluding from processing
#
#
# 1 Files with no RT struct file: ['00014_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00021
# S70 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00021/images
# S7040 5
# Case 00021 RT struct file
# Number of files in rt struct 6
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00021/labels/00021_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00021/labels/00021_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00021/labels/00021_Nodule_seg_1.nii.gz
# Saving struct Nodule_seg_2 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00021/labels/00021_Nodule_seg_2.nii.gz
# Saving struct Nodule_seg_3 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00021/labels/00021_Nodule_seg_3.nii.gz
# Saving struct Nodule_seg_4 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00021/labels/00021_Nodule_seg_4.nii.gz
#
#
# 1 Files with no RT struct file: ['00014_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00022
# S70 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00022/images
# S7040 5
# Case 00022 RT struct file
# Number of files in rt struct 6
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00022/labels/00022_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00022/labels/00022_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00022/labels/00022_Nodule_seg_1.nii.gz
# Saving struct Nodule_seg_2 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00022/labels/00022_Nodule_seg_2.nii.gz
# Saving struct Nodule_seg_3 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00022/labels/00022_Nodule_seg_3.nii.gz
# Saving struct Nodule_seg_4 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00022/labels/00022_Nodule_seg_4.nii.gz
#
#
# 1 Files with no RT struct file: ['00014_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00023
# S90 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00023/images
# S9040 5
# Case 00023 RT struct file
# Number of files in rt struct 4
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00023/labels/00023_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00023/labels/00023_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00023/labels/00023_Nodule_seg_1.nii.gz
# Saving struct Nodule_seg_2 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00023/labels/00023_Nodule_seg_2.nii.gz
#
#
# 1 Files with no RT struct file: ['00014_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00024
# S70 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00024/images
# S7040 5
# Case 00024 RT struct file
# Number of files in rt struct 3
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00024/labels/00024_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00024/labels/00024_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00024/labels/00024_Nodule_seg_1.nii.gz
#
#
# 1 Files with no RT struct file: ['00014_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00068
# S70 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00068/images
# S7040 5
# Case 00068 RT struct file
# Number of files in rt struct 4
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00068/labels/00068_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00068/labels/00068_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00068/labels/00068_Nodule_seg_1.nii.gz
# Saving struct Nodule_seg_2 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00068/labels/00068_Nodule_seg_2.nii.gz
#
#
# 1 Files with no RT struct file: ['00014_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00069
# S50 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00069/images
# S5040 5
# Case 00069 RT struct file
# Number of files in rt struct 5
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00069/labels/00069_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00069/labels/00069_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00069/labels/00069_Nodule_seg_1.nii.gz
# Saving struct Nodule_seg_2 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00069/labels/00069_Nodule_seg_2.nii.gz
# Saving struct Nodule_seg_3 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00069/labels/00069_Nodule_seg_3.nii.gz
#
#
# 1 Files with no RT struct file: ['00014_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
#
#
# 2 Files with no RT struct file: ['00014_', '00070_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00071
# S60 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00071/images
# S6040 5
# Case 00071 RT struct file
# Number of files in rt struct 3
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00071/labels/00071_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00071/labels/00071_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00071/labels/00071_Nodule_seg_1.nii.gz
#
#
# 2 Files with no RT struct file: ['00014_', '00070_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00072
# S70 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00072/images
# S7040 5
# Case 00072 RT struct file
# Number of files in rt struct 5
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00072/labels/00072_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00072/labels/00072_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00072/labels/00072_Nodule_seg_1.nii.gz
# Saving struct Nodule_seg_2 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00072/labels/00072_Nodule_seg_2.nii.gz
# Saving struct Nodule_seg_3 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00072/labels/00072_Nodule_seg_3.nii.gz
#
#
# 2 Files with no RT struct file: ['00014_', '00070_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00073
# S90 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00073/images
# S9040 5
# Case 00073 RT struct file
# Number of files in rt struct 2
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00073/labels/00073_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00073/labels/00073_Right_lung_seg.nii.gz
#
#
# 2 Files with no RT struct file: ['00014_', '00070_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00074
# S60 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00074/images
# S6050 5
# Case 00074 RT struct file
# Number of files in rt struct 6
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00074/labels/00074_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00074/labels/00074_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00074/labels/00074_Nodule_seg_1.nii.gz
# Saving struct Nodule_seg_2 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00074/labels/00074_Nodule_seg_2.nii.gz
# Saving struct Nodule_seg_3 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00074/labels/00074_Nodule_seg_3.nii.gz
# Saving struct Nodule_seg_4 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00074/labels/00074_Nodule_seg_4.nii.gz
#
#
# 2 Files with no RT struct file: ['00014_', '00070_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00075
# S70 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00075/images
# S7040 5
# Case 00075 RT struct file
# Number of files in rt struct 3
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00075/labels/00075_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00075/labels/00075_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00075/labels/00075_Nodule_seg_1.nii.gz
#
#
# 2 Files with no RT struct file: ['00014_', '00070_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00076
# S60 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00076/images
# S6040 5
# Case 00076 RT struct file
# Number of files in rt struct 5
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00076/labels/00076_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00076/labels/00076_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00076/labels/00076_Nodule_seg_1.nii.gz
# Saving struct Nodule_seg_2 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00076/labels/00076_Nodule_seg_2.nii.gz
# Saving struct Nodule_seg_3 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00076/labels/00076_Nodule_seg_3.nii.gz
#
#
# 2 Files with no RT struct file: ['00014_', '00070_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00077
# S50 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00077/images
# S5040 5
# Case 00077 RT struct file
# Number of files in rt struct 4
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00077/labels/00077_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00077/labels/00077_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00077/labels/00077_Nodule_seg_1.nii.gz
# Saving struct Nodule_seg_2 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00077/labels/00077_Nodule_seg_2.nii.gz
#
#
# 2 Files with no RT struct file: ['00014_', '00070_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00078
# S80 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00078/images
# S8040 5
# Case 00078 RT struct file
# Number of files in rt struct 6
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00078/labels/00078_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00078/labels/00078_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00078/labels/00078_Nodule_seg_1.nii.gz
# Saving struct Nodule_seg_2 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00078/labels/00078_Nodule_seg_2.nii.gz
# Saving struct Nodule_seg_3 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00078/labels/00078_Nodule_seg_3.nii.gz
# Saving struct Nodule_seg_4 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00078/labels/00078_Nodule_seg_4.nii.gz
#
#
# 2 Files with no RT struct file: ['00014_', '00070_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00079
# S50 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00079/images
# S5040 5
# Case 00079 RT struct file
# Number of files in rt struct 7
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00079/labels/00079_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00079/labels/00079_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00079/labels/00079_Nodule_seg_1.nii.gz
# Saving struct Nodule_seg_2 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00079/labels/00079_Nodule_seg_2.nii.gz
# Saving struct Nodule_seg_3 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00079/labels/00079_Nodule_seg_3.nii.gz
# Saving struct Nodule_seg_4 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00079/labels/00079_Nodule_seg_4.nii.gz
# Saving struct Nodule_seg_5 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00079/labels/00079_Nodule_seg_5.nii.gz
#
#
# 2 Files with no RT struct file: ['00014_', '00070_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00080
# S50 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00080/images
# S5060 5
# Case 00080 RT struct file
# Number of files in rt struct 3
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00080/labels/00080_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00080/labels/00080_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00080/labels/00080_Nodule_seg_1.nii.gz
#
#
# 2 Files with no RT struct file: ['00014_', '00070_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00081
# S70 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00081/images
#
#
# 2 Files with no RT struct file: ['00014_', '00070_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00082
# S70 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00082/images
# S7060 5
# Case 00082 RT struct file
# Number of files in rt struct 7
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00082/labels/00082_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00082/labels/00082_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00082/labels/00082_Nodule_seg_1.nii.gz
# Saving struct Nodule_seg_2 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00082/labels/00082_Nodule_seg_2.nii.gz
# Saving struct Nodule_seg_3 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00082/labels/00082_Nodule_seg_3.nii.gz
# Saving struct Nodule_seg_4 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00082/labels/00082_Nodule_seg_4.nii.gz
# Saving struct Nodule_seg_5 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00082/labels/00082_Nodule_seg_5.nii.gz
#
#
# 2 Files with no RT struct file: ['00014_', '00070_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00083
# S50 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00083/images
# S5040 5
# Case 00083 RT struct file
# Number of files in rt struct 7
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00083/labels/00083_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00083/labels/00083_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00083/labels/00083_Nodule_seg_1.nii.gz
# Saving struct Nodule_seg_2 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00083/labels/00083_Nodule_seg_2.nii.gz
# Saving struct Nodule_seg_3 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00083/labels/00083_Nodule_seg_3.nii.gz
# Saving struct Nodule_seg_4 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00083/labels/00083_Nodule_seg_4.nii.gz
# Saving struct Nodule_seg_5 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00083/labels/00083_Nodule_seg_5.nii.gz
#
#
# 2 Files with no RT struct file: ['00014_', '00070_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00084
# S70 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00084/images
# S7040 5
# Case 00084 RT struct file
# Number of files in rt struct 3
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00084/labels/00084_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00084/labels/00084_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00084/labels/00084_Nodule_seg_1.nii.gz
#
#
# 2 Files with no RT struct file: ['00014_', '00070_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00085
# S50 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00085/images
# S5060 5
# Case 00085 RT struct file
# Number of files in rt struct 3
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00085/labels/00085_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00085/labels/00085_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00085/labels/00085_Nodule_seg_1.nii.gz
#
#
# 2 Files with no RT struct file: ['00014_', '00070_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00086
# S50 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00086/images
# S5040 5
# Case 00086 RT struct file
# Number of files in rt struct 7
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00086/labels/00086_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00086/labels/00086_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00086/labels/00086_Nodule_seg_1.nii.gz
# Saving struct Nodule_seg_2 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00086/labels/00086_Nodule_seg_2.nii.gz
# Saving struct Nodule_seg_3 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00086/labels/00086_Nodule_seg_3.nii.gz
# Saving struct Nodule_seg_4 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00086/labels/00086_Nodule_seg_4.nii.gz
# Saving struct Nodule_seg_5 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00086/labels/00086_Nodule_seg_5.nii.gz
#
#
# 2 Files with no RT struct file: ['00014_', '00070_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00087
# S50 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00087/images
# S5040 5
# Case 00087 RT struct file
# Number of files in rt struct 2
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00087/labels/00087_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00087/labels/00087_Right_lung_seg.nii.gz
#
#
# 2 Files with no RT struct file: ['00014_', '00070_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00088
# S106890 7
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00088/images
# S106920 7
# Case 00088 RT struct file
# Number of files in rt struct 4
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00088/labels/00088_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00088/labels/00088_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00088/labels/00088_Nodule_seg_1.nii.gz
# Saving struct Nodule_seg_2 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00088/labels/00088_Nodule_seg_2.nii.gz
#
#
# 2 Files with no RT struct file: ['00014_', '00070_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00089
# S70 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00089/images
# S7040 5
# Case 00089 RT struct file
# Number of files in rt struct 2
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00089/labels/00089_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00089/labels/00089_Right_lung_seg.nii.gz
#
#
# 2 Files with no RT struct file: ['00014_', '00070_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00090
# S50 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00090/images
# S5050 5
# Case 00090 RT struct file
# Number of files in rt struct 3
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00090/labels/00090_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00090/labels/00090_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00090/labels/00090_Nodule_seg_1.nii.gz
#
#
# 2 Files with no RT struct file: ['00014_', '00070_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00091
# S70 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00091/images
# S7040 5
# Case 00091 RT struct file
# Number of files in rt struct 3
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00091/labels/00091_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00091/labels/00091_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00091/labels/00091_Nodule_seg_1.nii.gz
#
#
# 2 Files with no RT struct file: ['00014_', '00070_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00092
# S50 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00092/images
# S5040 5
# Case 00092 RT struct file
# Number of files in rt struct 2
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00092/labels/00092_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00092/labels/00092_Right_lung_seg.nii.gz
#
#
# 2 Files with no RT struct file: ['00014_', '00070_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00093
# S70 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00093/images
# S7040 5
# Case 00093 RT struct file
# Number of files in rt struct 3
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00093/labels/00093_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00093/labels/00093_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00093/labels/00093_Nodule_seg_1.nii.gz
#
#
# 2 Files with no RT struct file: ['00014_', '00070_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00094
# S50 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00094/images
# S5040 5
# Case 00094 RT struct file
# Number of files in rt struct 3
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00094/labels/00094_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00094/labels/00094_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00094/labels/00094_Nodule_seg_1.nii.gz
#
#
# 2 Files with no RT struct file: ['00014_', '00070_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00095
# S70 3
# ...
# Saving struct Nodule_seg_3 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00038/labels/00038_Nodule_seg_3.nii.gz
#
#
# 3 Files with no RT struct file: ['00014_', '00070_', '00150_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00039
# S50 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00039/images
# S500050 7
# Case 00039 RT struct file
# Number of files in rt struct 3
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00039/labels/00039_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00039/labels/00039_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00039/labels/00039_Nodule_seg_1.nii.gz
#
#
# 3 Files with no RT struct file: ['00014_', '00070_', '00150_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00040
# S70 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00040/images
# S7040 5
# Case 00040 RT struct file
# Number of files in rt struct 12
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00040/labels/00040_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00040/labels/00040_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00040/labels/00040_Nodule_seg_1.nii.gz
# Saving struct Nodule_seg_2 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00040/labels/00040_Nodule_seg_2.nii.gz
# Saving struct Nodule_seg_3 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00040/labels/00040_Nodule_seg_3.nii.gz
# Saving struct Nodule_seg_4 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00040/labels/00040_Nodule_seg_4.nii.gz
# Saving struct Nodule_seg_5 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00040/labels/00040_Nodule_seg_5.nii.gz
# Saving struct Nodule_seg_6 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00040/labels/00040_Nodule_seg_6.nii.gz
# Saving struct Nodule_seg_7 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00040/labels/00040_Nodule_seg_7.nii.gz
# Saving struct Nodule_seg_8 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00040/labels/00040_Nodule_seg_8.nii.gz
# Saving struct Nodule_seg_9 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00040/labels/00040_Nodule_seg_9.nii.gz
# Saving struct Nodule_seg_10 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00040/labels/00040_Nodule_seg_10.nii.gz
#
#
# 3 Files with no RT struct file: ['00014_', '00070_', '00150_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00041
# S50 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00041/images
# S5040 5
# Case 00041 RT struct file
# Number of files in rt struct 3
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00041/labels/00041_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00041/labels/00041_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00041/labels/00041_Nodule_seg_1.nii.gz
#
#
# 3 Files with no RT struct file: ['00014_', '00070_', '00150_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00042
# S70 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00042/images
# S7040 5
# Case 00042 RT struct file
# Number of files in rt struct 2
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00042/labels/00042_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00042/labels/00042_Right_lung_seg.nii.gz
#
#
# 3 Files with no RT struct file: ['00014_', '00070_', '00150_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00043
# S50 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00043/images
# S5040 5
# Case 00043 RT struct file
# Number of files in rt struct 9
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00043/labels/00043_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00043/labels/00043_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00043/labels/00043_Nodule_seg_1.nii.gz
# Saving struct Nodule_seg_2 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00043/labels/00043_Nodule_seg_2.nii.gz
# Saving struct Nodule_seg_3 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00043/labels/00043_Nodule_seg_3.nii.gz
# Saving struct Nodule_seg_4 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00043/labels/00043_Nodule_seg_4.nii.gz
# Saving struct Nodule_seg_5 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00043/labels/00043_Nodule_seg_5.nii.gz
# Saving struct Nodule_seg_6 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00043/labels/00043_Nodule_seg_6.nii.gz
# Saving struct Nodule_seg_7 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00043/labels/00043_Nodule_seg_7.nii.gz
#
#
# 3 Files with no RT struct file: ['00014_', '00070_', '00150_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
#
#
# 4 Files with no RT struct file: ['00014_', '00070_', '00150_', '00044_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00045
# S50 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00045/images
# S5040 5
# Case 00045 RT struct file
# Number of files in rt struct 5
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00045/labels/00045_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00045/labels/00045_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00045/labels/00045_Nodule_seg_1.nii.gz
# Saving struct Nodule_seg_2 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00045/labels/00045_Nodule_seg_2.nii.gz
# Saving struct Nodule_seg_3 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00045/labels/00045_Nodule_seg_3.nii.gz
#
#
# 4 Files with no RT struct file: ['00014_', '00070_', '00150_', '00044_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00046
# S80 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00046/images
# S8040 5
# Case 00046 RT struct file
# Number of files in rt struct 3
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00046/labels/00046_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00046/labels/00046_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00046/labels/00046_Nodule_seg_1.nii.gz
#
#
# 4 Files with no RT struct file: ['00014_', '00070_', '00150_', '00044_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00047
# S50 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00047/images
# S5040 5
# Case 00047 RT struct file
# Number of files in rt struct 5
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00047/labels/00047_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00047/labels/00047_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00047/labels/00047_Nodule_seg_1.nii.gz
# Saving struct Nodule_seg_2 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00047/labels/00047_Nodule_seg_2.nii.gz
# Saving struct Nodule_seg_3 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00047/labels/00047_Nodule_seg_3.nii.gz
#
#
# 4 Files with no RT struct file: ['00014_', '00070_', '00150_', '00044_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00048
# S70 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00048/images
# S7050 5
# Case 00048 RT struct file
# Number of files in rt struct 3
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00048/labels/00048_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00048/labels/00048_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00048/labels/00048_Nodule_seg_1.nii.gz
#
#
# 4 Files with no RT struct file: ['00014_', '00070_', '00150_', '00044_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00049
# S50 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00049/images
# S5040 5
# Case 00049 RT struct file
# Number of files in rt struct 6
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00049/labels/00049_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00049/labels/00049_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00049/labels/00049_Nodule_seg_1.nii.gz
# Saving struct Nodule_seg_2 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00049/labels/00049_Nodule_seg_2.nii.gz
# Saving struct Nodule_seg_3 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00049/labels/00049_Nodule_seg_3.nii.gz
# Saving struct Nodule_seg_4 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00049/labels/00049_Nodule_seg_4.nii.gz
#
#
# 4 Files with no RT struct file: ['00014_', '00070_', '00150_', '00044_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00050
# S50 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00050/images
# S5040 5
# Case 00050 RT struct file
# Number of files in rt struct 4
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00050/labels/00050_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00050/labels/00050_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00050/labels/00050_Nodule_seg_1.nii.gz
# Saving struct Nodule_seg_2 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00050/labels/00050_Nodule_seg_2.nii.gz
#
#
# 4 Files with no RT struct file: ['00014_', '00070_', '00150_', '00044_']
#
# 1 files with more than one RT struct file: ['00020']
#
#
# 1 Files with multiple CT files: ['00020']
# case num:  00051
# S500000 7
# Case: 00051 has more RT struct files than 1! N files in folder data_f: 81, ['I410', 'I630', 'I10', 'I100', 'I110', 'I120', 'I130', 'I140', 'I150', 'I160', 'I170', 'I180', 'I190', 'I20', 'I200', 'I210', 'I220', 'I230', 'I240', 'I250', 'I260', 'I270', 'I280', 'I290', 'I30', 'I300', 'I310', 'I320', 'I330', 'I340', 'I350', 'I360', 'I370', 'I380', 'I390', 'I40', 'I400', 'I420', 'I430', 'I440', 'I450', 'I460', 'I470', 'I480', 'I490', 'I50', 'I500', 'I510', 'I520', 'I530', 'I540', 'I550', 'I560', 'I570', 'I580', 'I590', 'I60', 'I600', 'I610', 'I620', 'I640', 'I650', 'I660', 'I670', 'I680', 'I690', 'I70', 'I700', 'I710', 'I720', 'I730', 'I740', 'I750', 'I760', 'I770', 'I780', 'I790', 'I80', 'I800', 'I810', 'I90']
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00051/images
# S80 3
# Case 00051 contains several folders with more than one file. Excluding from processing
#
#
# 4 Files with no RT struct file: ['00014_', '00070_', '00150_', '00044_']
#
# 2 files with more than one RT struct file: ['00020', '00051']
#
#
# 2 Files with multiple CT files: ['00020', '00051']
# case num:  00052
# S70 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00052/images
# S7040 5
# Case 00052 RT struct file
# Number of files in rt struct 3
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00052/labels/00052_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00052/labels/00052_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00052/labels/00052_Nodule_seg_1.nii.gz
#
#
# 4 Files with no RT struct file: ['00014_', '00070_', '00150_', '00044_']
#
# 2 files with more than one RT struct file: ['00020', '00051']
#
#
# 2 Files with multiple CT files: ['00020', '00051']
# case num:  00053
# S22040 6
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00053/images
# S22090 6
# Case 00053 RT struct file
# Number of files in rt struct 10
# Saving struct Left _lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00053/labels/00053_Left _lung_seg.nii.gz
# Saving struct Right_lung_seg to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00053/labels/00053_Right_lung_seg.nii.gz
# Saving struct Nodule_seg_1 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00053/labels/00053_Nodule_seg_1.nii.gz
# Saving struct Nodule_seg_2 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00053/labels/00053_Nodule_seg_2.nii.gz
# Saving struct Nodule_seg_3 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00053/labels/00053_Nodule_seg_3.nii.gz
# Saving struct Nodule_seg_4 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00053/labels/00053_Nodule_seg_4.nii.gz
# Saving struct Nodule_seg_5 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00053/labels/00053_Nodule_seg_5.nii.gz
# Saving struct Nodule_seg_6 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00053/labels/00053_Nodule_seg_6.nii.gz
# Saving struct Nodule_seg_7 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00053/labels/00053_Nodule_seg_7.nii.gz
# Saving struct Nodule_seg_8 to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00053/labels/00053_Nodule_seg_8.nii.gz
#
#
# 4 Files with no RT struct file: ['00014_', '00070_', '00150_', '00044_']
#
# 2 files with more than one RT struct file: ['00020', '00051']
#
#
# 2 Files with multiple CT files: ['00020', '00051']
# case num:  00054
# S80 3
# Saving resized file to /media/terese/New Volume1/Lung_cancer_project/ISP_dataset/NIFTY_Data/00054/images
